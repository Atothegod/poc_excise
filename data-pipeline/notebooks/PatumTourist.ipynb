# %%
import requests
import pandas as pd
import os
from pathlib import Path
from datetime import datetime, timedelta # เพิ่ม timedelta
from typing import List, Dict, Any

API_KEY = os.getenv("RAPIDAPI_KEY", "5a74f09b58mshcc53e8477cbeb6dp1c0595jsncee572e27ef4")
API_HOST = "facebook-scraper3.p.rapidapi.com"
BASE_URL = f"https://{API_HOST}/page/posts"

DESKTOP_PATH = Path.home() / "Desktop" / "PatumTourist"
DESKTOP_PATH.mkdir(parents=True, exist_ok=True)

HEADERS = {
    "x-rapidapi-key": API_KEY,
    "x-rapidapi-host": API_HOST,
    "Content-Type": "application/json"
}
print(f"✅ เตรียมโฟลเดอร์เก็บข้อมูลที่: {DESKTOP_PATH}")
# Out:
# ✅ เตรียมโฟลเดอร์เก็บข้อมูลที่: /Users/palmchns/Desktop/PatumTourist

# %%
# Cell 2: Fetch 10 Latest Posts
def fetch_latest_10_posts(page_id: str) -> List[Dict[str, Any]]:
    """ดึงข้อมูล 10 โพสต์ล่าสุดจากหน้าแรก (ใช้ตรรกะเดิมของคุณที่ได้ข้อมูลใหม่สุด)"""
    
    # ส่งแค่ page_id อย่างเดียว เพื่อบังคับให้ API ดึงจากหน้าวอลล์ล่าสุดโดยตรง
    querystring = {"page_id": page_id}
    
    try:
        print(f"⏳ กำลังดึง 10 โพสต์ล่าสุดจาก ID: {page_id}...")
        response = requests.get(BASE_URL, headers=HEADERS, params=querystring, timeout=20)
        response.raise_for_status()
        
        data = response.json()
        all_posts = data.get('results') or data.get('data') or (data if isinstance(data, list) else [])
        
        # ตัดเอาแค่ 10 โพสต์แรก
        latest_10 = all_posts[:10]
        return latest_10, all_posts
        
    except Exception as e:
        print(f"❌ Error: {e}")
        return []

# %%
def get_existing_post_ids(folder_path: Path) -> set:
    existing_ids = set()
    for file in folder_path.glob("*.parquet"):
        try:
            temp_df = pd.read_parquet(file)
            if 'id' in temp_df.columns:
                existing_ids.update(temp_df['id'].astype(str).tolist())
        except Exception as e:
            pass
    return existing_ids

def save_new_posts_to_parquet(new_posts: List[Dict[str, Any]], folder_path: Path) -> pd.DataFrame:
    if not new_posts:
        print("ℹ️ ไม่มีข้อมูลให้ประมวลผล")
        return pd.DataFrame()

    # 🌟 ดึงข้อมูลแบบยืดหยุ่น ป้องกันคีย์หาย
    processed_data = []
    for post in new_posts:
        content = post.get('message') or post.get('text') or post.get('description') or ""
        raw_date = post.get('created_time') or post.get('time') or post.get('timestamp')
        post_id = str(post.get('id') or post.get('post_id') or "")
        
        if post_id:
            processed_data.append({'id': post_id, 'post_date': raw_date, 'post_content': content})
            
    df_new = pd.DataFrame(processed_data)
    
    existing_ids = get_existing_post_ids(folder_path)
    df_filtered = df_new[~df_new['id'].isin(existing_ids)].copy()

    if df_filtered.empty:
        print("✨ ทุกโพสต์ที่ดึงมา มีอยู่ในเครื่องแล้ว (ไม่มีข้อมูลใหม่)")
        return pd.DataFrame()

    if 'post_date' in df_filtered.columns:
        is_timestamp = str(df_filtered['post_date'].dropna().iloc[0]).replace('.', '', 1).isdigit()
        if is_timestamp:
            df_filtered['post_date'] = pd.to_datetime(df_filtered['post_date'].astype(float), unit='s', errors='coerce')
        else:
            df_filtered['post_date'] = pd.to_datetime(df_filtered['post_date'], format='mixed', errors='coerce')

    final_df = df_filtered[['id', 'post_date', 'post_content']].sort_values(by='post_date', ascending=False)

    today_str = datetime.now().strftime("%Y-%m-%d")
    filename = folder_path / f"fb_posts_{today_str}.parquet"
    final_df.to_parquet(filename, index=False, engine='pyarrow')
    
    print(f"🎉 บันทึกข้อมูลใหม่ {len(final_df)} โพสต์ ลงในไฟล์: {filename.name}")
    
    # 🌟 ต้อง Return ค่าออกมาเพื่อให้ข้างนอกเรียกดูได้
    return final_df

# %%
if __name__ == "__main__":
    PAGE_ID = "100068138844126" # PatumTourist
    
    # 1. ดึงข้อมูล 
    raw_data, all_post = fetch_latest_10_posts(PAGE_ID)
    
    # 2. กรองตัวซ้ำ, เซฟลง Parquet และ "รับค่า DataFrame" กลับมา
    final_df = save_new_posts_to_parquet(raw_data, DESKTOP_PATH)
    
    # 3. โชว์ผลลัพธ์
    if not final_df.empty:
        display(final_df) # โชว์ตารางสวยๆ
# Out:
# ⏳ กำลังดึง 10 โพสต์ล่าสุดจาก ID: 100068138844126...
# 🎉 บันทึกข้อมูลใหม่ 3 โพสต์ ลงในไฟล์: fb_posts_2026-03-31.parquet
#                  id           post_date  \
# 0  1264183465862936 2026-03-31 07:45:27
# 1  1263450289269587 2026-03-31 02:00:03
# 2  1264015452546404 2026-03-31 01:57:08
#
#                                         post_content
# 0  ดอกบัวหลวง สวนเทพปทุม ในสระน้ำหน้าหอคอย สวยจนต...
# 1  🤖🔥 Click Robot Fighting\nเปิดศึกการแข่งขันหุ่น...
# 2  ร้านนี้ของดีตลาดปทุม #ชายขายกล้วย ที่ขายมากว่า...

# %%
pd.DataFrame({
    "post_id": [],
    "timestamp": [],
    "name???": [],
    "platform": [],
    "raw_text": [],
    "post_url": [],
})
# Out:
# Empty DataFrame
# Columns: [post_id, timestamp, platform, raw_text, post_url]
# Index: []

# %%
all_post[0]
# Out:
# {'post_id': '1264183465862936',
#  'type': 'post',
#  'url': 'https://www.facebook.com/PatumTourist/posts/pfbid0gugkdzE6gTDZfgZs9wtMCj7ULtEz56BbNR1UEo6NATYpbSUsEGmwTCdDJdRz4QwAl',
#  'message': 'ดอกบัวหลวง สวนเทพปทุม ในสระน้ำหน้าหอคอย สวยจนต้องหยุดถ่ายรูป \U0001fab7😍#สวนเทพปทุม #ตลาดปทุม #ปทุมธานี #ปทุมน่าเที่ยว',
#  'message_rich': 'ดอกบัวหลวง สวนเทพปทุม ในสระน้ำหน้าหอคอย สวยจนต้องหยุดถ่ายรูป \U0001fab7😍#สวนเทพปทุม #ตลาดปทุม #ปทุมธานี #ปทุมน่าเที่ยว',
#  'timestamp': 1774943127,
#  'comments_count': 0,
#  'reactions_count': 7,
#  'reshare_count': 0,
#  'reactions': {'angry': 0,
#   'care': 0,
#   'haha': 0,
#   'like': 7,
#   'love': 0,
#   'sad': 0,
#   'wow': 0},
#  'author': {'id': '100068138844126',
#   'name': 'ปทุมน่าเที่ยว',
#   'url': 'https://www.facebook.com/PatumTourist',
#   'profile_picture_url': 'https://scontent.fgye10-1.fna.fbcdn.net/v/t39.30808-1/601360209_1186702230277727_2281778521165270996_n.jpg?stp=cp0_dst-jpg_s40x40_tt6&_nc_cat=100&ccb=1-7&_nc_sid=2d3e12&_nc_ohc=NCwRMIT95bsQ7kNvwFhiAG5&_nc_oc=AdrneK4CxH51Cqjxs8R8N72lqxwbpvSFM0D4ywpjAPlY3Zxl7TC5PA2Of8SPR9LT-lA&_nc_zt=24&_nc_ht=scontent.fgye10-1.fna&_nc_gid=rYiQfM5u-aozVYbwh4oXbw&_nc_ss=7a389&oh=00_Afw6h9CfIgAF0VSCekInYAo4ZU0DJSSai2w-sYQbNFK4zQ&oe=69D15458'},
#  'author_title': None,
#  'image': {'uri': 'https://scontent.fgye10-2.fna.fbcdn.net/v/t39.30808-6/662133829_1264182465863036_3571965969621142370_n.jpg?stp=dst-jpg_s640x640_tt6&_nc_cat=103&ccb=1-7&_nc_sid=7b2446&_nc_ohc=9K_A77QbcOEQ7kNvwH7MJ0f&_nc_oc=AdpGSZlcgGoMkRpxesetvvjtmPVX_Fq3Bj5H-vfqVvIJs-UeguC7RAU76U_B4dKCuio&_nc_zt=23&_nc_ht=scontent.fgye10-2.fna&_nc_gid=rYiQfM5u-aozVYbwh4oXbw&_nc_ss=7a389&oh=00_AfyJKoHfwwJiXrm3L92CaM2Kws_38j2z5-x73choP_MWSA&oe=69D169CD',
#   'height': 640,
#   'width': 504,
#   'id': '1264182462529703'},
#  'video': None,
#  'album_preview': None,
#  'video_files': None,
#  'video_thumbnail': None,
#  'external_url': None,
#  'attached_event': None,
#  'attached_post': None,
#  'attached_post_url': None,
#  'text_format_metadata': None,
#  'comments_id': '1264183465862936',
#  'shares_id': '1264183465862936'}
